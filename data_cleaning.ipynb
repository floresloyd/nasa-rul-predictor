# %%
import pandas as pd

# %% [markdown]
# # Setting up initial dataset

# %%
# Define the column names
column_names = [
    'UnitNumber', 'TimeInCycles', 'OperationalSetting1', 'OperationalSetting2', 'OperationalSetting3',
    'SensorMeasurement1', 'SensorMeasurement2', 'SensorMeasurement3', 'SensorMeasurement4', 'SensorMeasurement5',
    'SensorMeasurement6', 'SensorMeasurement7', 'SensorMeasurement8', 'SensorMeasurement9', 'SensorMeasurement10',
    'SensorMeasurement11', 'SensorMeasurement12', 'SensorMeasurement13', 'SensorMeasurement14', 'SensorMeasurement15',
    'SensorMeasurement16', 'SensorMeasurement17', 'SensorMeasurement18', 'SensorMeasurement19', 'SensorMeasurement20',
    'SensorMeasurement21'
]

train1 = pd.read_excel("Data/Book1.xlsx") # load excel file a variable
train1 = train1.iloc[:, :-2]              # remove last 2 cols, they are empty
train1.columns = column_names             # change col names
train1.head(5)
# Out:
#    UnitNumber  TimeInCycles  OperationalSetting1  OperationalSetting2  \
# 0           1             1              -0.0007              -0.0004
# 1           1             2               0.0019              -0.0003
# 2           1             3              -0.0043               0.0003
# 3           1             4               0.0007               0.0000
# 4           1             5              -0.0019              -0.0002
#
#    OperationalSetting3  SensorMeasurement1  SensorMeasurement2  \
# 0                  100              518.67              641.82
# 1                  100              518.67              642.15
# 2                  100              518.67              642.35
# 3                  100              518.67              642.35
# 4                  100              518.67              642.37
#
#    SensorMeasurement3  SensorMeasurement4  SensorMeasurement5  ...  \
# 0             1589.70             1400.60               14.62  ...
# ...

# %%
train2 = pd.read_excel("Data/train2.xlsx")   # load excel file a variable
#train2 = train2.iloc[:, :-2]                # remove last 2 cols, they are empty
train2.columns = column_names                # change col names
train2.head(5)
# Out:
#    UnitNumber  TimeInCycles  OperationalSetting1  OperationalSetting2  \
# 0           1             1              34.9983               0.8400
# 1           1             2              41.9982               0.8408
# 2           1             3              24.9988               0.6218
# 3           1             4              42.0077               0.8416
# 4           1             5              25.0005               0.6203
#
#    OperationalSetting3  SensorMeasurement1  SensorMeasurement2  \
# 0                  100              449.44              555.32
# 1                  100              445.00              549.90
# 2                   60              462.54              537.31
# 3                  100              445.00              549.51
# 4                   60              462.54              537.07
#
#    SensorMeasurement3  SensorMeasurement4  SensorMeasurement5  ...  \
# 0             1358.61             1137.23                5.48  ...
# ...

# %%
train3 = pd.read_excel("Data/train3.xlsx")   # load excel file a variable
train3 = train3.iloc[:, :-2]                # remove last 2 cols, they are empty
train3.columns = column_names                # change col names
train3.head(5)
# Out:
#    UnitNumber  TimeInCycles  OperationalSetting1  OperationalSetting2  \
# 0           1             1              -0.0005               0.0004
# 1           1             2               0.0008              -0.0003
# 2           1             3              -0.0014              -0.0002
# 3           1             4              -0.0020               0.0001
# 4           1             5               0.0016               0.0000
#
#    OperationalSetting3  SensorMeasurement1  SensorMeasurement2  \
# 0                  100              518.67              642.36
# 1                  100              518.67              642.50
# 2                  100              518.67              642.18
# 3                  100              518.67              642.92
# 4                  100              518.67              641.68
#
#    SensorMeasurement3  SensorMeasurement4  SensorMeasurement5  ...  \
# 0             1583.23             1396.84               14.62  ...
# ...

# %%
train4 = pd.read_excel("Data/train4.xlsx")   # load excel file a variable
train4 = train4.iloc[:, :-2]                # remove last 2 cols, they are empty
train4.columns = column_names                # change col names
train4.head(5)
# Out:
#    UnitNumber  TimeInCycles  OperationalSetting1  OperationalSetting2  \
# 0           1             1              42.0049               0.8400
# 1           1             2              20.0020               0.7002
# 2           1             3              42.0038               0.8409
# 3           1             4              42.0000               0.8400
# 4           1             5              25.0063               0.6207
#
#    OperationalSetting3  SensorMeasurement1  SensorMeasurement2  \
# 0                  100              445.00              549.68
# 1                  100              491.19              606.07
# 2                  100              445.00              548.95
# 3                  100              445.00              548.70
# 4                   60              462.54              536.10
#
#    SensorMeasurement3  SensorMeasurement4  SensorMeasurement5  ...  \
# 0             1343.43             1112.93                3.91  ...
# ...

# %%
# Read and store label 
test1 = pd.read_excel("Data/RUL_FD001.xlsx")
test2 = pd.read_excel("Data/RUL_FD002.xlsx")
test3 = pd.read_excel("Data/RUL_FD003.xlsx")
test4 = pd.read_excel("Data/RUL_FD004.xlsx")

# %%
complete_train = pd.concat([train1, train2, train3, train4], axis=0)
complete_test = pd.concat([test1, test2, test3, test4], axis=0)
complete_test = complete_test.iloc[:, :-1]

# %%
complete_train.head()
# Out:
#    UnitNumber  TimeInCycles  OperationalSetting1  OperationalSetting2  \
# 0           1             1              -0.0007              -0.0004
# 1           1             2               0.0019              -0.0003
# 2           1             3              -0.0043               0.0003
# 3           1             4               0.0007               0.0000
# 4           1             5              -0.0019              -0.0002
#
#    OperationalSetting3  SensorMeasurement1  SensorMeasurement2  \
# 0                  100              518.67              641.82
# 1                  100              518.67              642.15
# 2                  100              518.67              642.35
# 3                  100              518.67              642.35
# 4                  100              518.67              642.37
#
#    SensorMeasurement3  SensorMeasurement4  SensorMeasurement5  ...  \
# 0             1589.70             1400.60               14.62  ...
# ...

# %%
complete_test.head(5)
# Out:
#      RUL
# 0  112.0
# 1   98.0
# 2   69.0
# 3   82.0
# 4   91.0

# %%
#complete_train.to_csv('complete_train.csv', index=False)
complete_test.to_csv('complete_test.csv', index=False)
